# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import os

from brisk.visualization import plots_imu
from brisk.analysis import parameters
from brisk.utils import path

# %% [markdown]
# # Get all subjects

# %%
subjects = path.get_subjects()
print('Subjects found:')
for s in subjects:
    print(f'\t{s}')
# Out:
# Subjects found:
# 	giovanni
# 	luca
# 	micheal
# 	simone

# %% [markdown]
# # Get parameters from all subjects

# %%
all_data = []
glob = []
for s in subjects:
    dd = parameters.cycle_parameters(s)
    gg = parameters.global_parameters(s)
    dd['subject'] = s
    gg['subject'] = s
    all_data.append(dd)
    glob.append(gg)

all_data = pd.concat(all_data, axis=0, ignore_index=True)
glob = pd.concat(glob, axis=0, ignore_index=True)
all_data.head()
# Out:
# Loading saved cycle parameters...
# Loading saved global parameters...
# Loading saved cycle parameters...
# Loading saved global parameters...
# Loading saved cycle parameters...
# Loading saved global parameters...
# Loading saved cycle parameters...
# Loading saved global parameters...
#   trial  event segment dimension  smoothness_acc  range_acc   rms_acc  \
# 0  full      0   trunk         x        3.327349   0.987371  0.194314
# 1  full      0   trunk         y        3.171827   4.302889  0.951458
# 2  full      0   trunk         z        4.835640   2.026462  0.634077
# 3  full      0     arm         x        2.598809   3.773039  0.965264
# 4  full      0     arm         y        0.175284   8.637375  1.712343
#
#    smoothness_gyr   range_gyr    rms_gyr   subject
# 0       -0.250937   66.394186  15.791713  giovanni
# 1        0.026196   37.458373   8.757628  giovanni
# 2        0.864151   49.356828   9.938376  giovanni
# 3       -3.376085  313.264193  58.468377  giovanni
# 4       -1.868011  132.235722  32.914085  giovanni

# %% [markdown]
# # Accelerometer

# %% [markdown]
# ## Trunk

# %%
plots_imu.plot_parameters(all_data, 'trunk', 'acc')

# %% [markdown]
# ## Arm

# %%
plots_imu.plot_parameters(all_data, 'arm', 'acc')

# %% [markdown]
# ## Forearm

# %%
plots_imu.plot_parameters(all_data, 'forearm', 'acc')

# %% [markdown]
# # Gyroscope

# %% [markdown]
# ## Trunk

# %%
plots_imu.plot_parameters(all_data, 'trunk', 'gyr')

# %% [markdown]
# ## Arm

# %%
plots_imu.plot_parameters(all_data, 'arm', 'gyr')

# %% [markdown]
# ## Forearm

# %%
plots_imu.plot_parameters(all_data, 'forearm', 'gyr')

# %% [markdown]
# # Global parameters

# %%
glob.sort_values(axis=0,by=['segment','dimension']).set_index(['segment','dimension','trial','subject']).groupby(level=['dimension','segment','trial']).mean()
# Out:
#                                     smoothness_acc  range_acc   rms_acc  \
# dimension segment trial
# global    arm     full                    0.939000   9.120038  1.922942
#                   full_robot              1.000980   8.952191  1.720242
#                   half_robot              0.697624   7.508591  1.526995
#                   half_robot_touch        0.768943   7.773984  1.577397
#           forearm full                    0.886254   9.645333  2.047158
#                   full_robot              0.869410   9.253025  1.676342
#                   half_robot              0.867154   7.998909  1.736237
#                   half_robot_touch        0.686674   7.974777  1.631084
#           trunk   full                    2.956554   3.156317  0.806357
#                   full_robot              2.587167   1.436852  0.287099
#                   half_robot              2.652822   2.098519  0.447003
#                   half_robot_touch        2.735119   2.360972  0.482487
# x         arm     full                    2.097472   4.359215  0.996790
#                   full_robot              1.060963   2.858123  0.402622
#                   half_robot              1.134295   3.072362  0.597338
#                   half_robot_touch        1.495631   3.624856  0.703235
#           forearm full                    1.211040  10.721592  2.424800
#                   full_robot              1.368481  10.142662  2.217814
#                   half_robot              1.102060  10.325794  2.251903
#                   half_robot_touch        1.013145  10.239260  2.046879
#           trunk   full                    3.623624   0.943921  0.218988
#                   full_robot              2.886523   0.472370  0.079416
#                   half_robot              3.053341   0.468386  0.086204
#                   half_robot_touch        3.062063   0.513844  0.093252
# y         arm     full                    0.804528   7.817064  1.786767
#                   full_robot              0.903592   6.526246  1.168774
#                   half_robot              1.055763   7.513583  1.788367
#                   half_robot_touch        0.791458   8.083484  1.833763
#           forearm full                    0.981309  12.407626  2.650806
#                   full_robot              1.164578   9.834763  2.277976
#                   half_robot              0.717381  10.560197  2.104422
#                   half_robot_touch        0.487722  10.734459  1.974943
#           trunk   full                    2.937688   5.741310  1.285695
#                   full_robot              1.929489   2.008840  0.294589
#                   half_robot              2.879060   3.363376  0.709521
#                   half_robot_touch        2.662403   3.571256  0.683873
# z         arm     full                    2.418473   6.296674  1.577008
#                   full_robot              1.777601   3.628481  0.679863
#                   half_robot              1.980348   4.472463  1.021827
#                   half_robot_touch        1.881625   4.721901  1.035175
#           forearm full                    1.680400  11.767758  2.691131
#                   full_robot              0.876930   9.300353  1.417343
#                   half_robot              1.495873   9.083267  1.977252
#                   half_robot_touch        1.202887   9.140279  1.879147
#           trunk   full                    4.158443   2.256993  0.611977
#                   full_robot              3.585620   1.704930  0.382595
#                   half_robot              3.818285   1.568030  0.387133
#                   half_robot_touch        3.802243   1.684041  0.412190
#
#                                     smoothness_gyr   range_gyr    rms_gyr  \
# dimension segment trial
# global    arm     full                   -2.534995  251.056642  57.054852
#                   full_robot             -2.762595  256.276872  48.277245
#                   half_robot             -2.743426  238.402948  51.574439
#                   half_robot_touch       -2.529473  280.042458  64.673291
#           forearm full                   -2.637254  228.104753  50.365926
#                   full_robot             -2.919869  231.212645  40.316427
#                   half_robot             -2.756765  232.808170  47.282170
#                   half_robot_touch       -2.661896  245.659261  52.872987
#           trunk   full                   -0.380488   64.774389  15.097583
#                   full_robot             -0.808741   50.291898  11.335834
#                   half_robot             -0.706016   45.254918  11.248007
#                   half_robot_touch       -0.447586   44.877891  11.555706
# x         arm     full                   -3.065106  243.773904  47.278599
#                   full_robot             -4.211400  205.636898  23.369097
#                   half_robot             -3.477649  228.606181  38.680145
#                   half_robot_touch       -3.152826  259.694538  43.748063
#           forearm full                   -2.690371  372.422448  70.641361
#                   full_robot             -3.951779  357.579425  37.762673
#                   half_robot             -3.108983  375.650060  61.523285
#                   half_robot_touch       -3.251109  383.326398  58.216488
#           trunk   full                   -0.382509   91.523298  20.858190
#                   full_robot             -1.194164   86.187521  13.385304
#                   half_robot             -0.425348   78.576218  17.997748
#                   half_robot_touch       -0.393964   76.362909  16.400368
# y         arm     full                   -1.738983  153.129644  33.385441
#                   full_robot             -3.045003  116.320067  13.337100
#                   half_robot             -2.044168  130.863255  24.734737
#                   half_robot_touch       -2.144518  142.565877  26.488482
#           forearm full                   -1.516574  208.237057  46.478049
#                   full_robot             -2.914899  143.004466  17.726928
#                   half_robot             -2.278555  144.237766  28.007862
#                   half_robot_touch       -1.897279  224.559084  40.751220
#           trunk   full                    0.798875   38.385902   9.107955
#                   full_robot             -0.479505   24.978149   3.708679
#                   half_robot              0.498278   23.573742   5.171668
#                   half_robot_touch        0.375494   25.048893   5.226793
# z         arm     full                   -1.419284  238.083304  52.846450
#                   full_robot             -2.396432  194.374289  24.077943
#                   half_robot             -1.651228  232.766699  45.476425
#                   half_robot_touch       -2.044919  231.549600  45.562979
#           forearm full                   -1.910714  220.128275  46.453296
#                   full_robot             -2.643525  204.657004  27.906864
#                   half_robot             -2.239443  191.817057  37.565634
#                   half_robot_touch       -2.466595  214.776071  40.308662
#           trunk   full                    0.429744   61.560789  14.242212
#                   full_robot             -0.666448   29.094405   4.536239
#                   half_robot              0.542113   39.758280   8.553691
#                   half_robot_touch        0.309992   44.582669   8.550636
#
#                                     n_events  regularity_acc  regularity_gyr
# dimension segment trial
# global    arm     full                 69.25        0.062471        0.161686
#                   full_robot           17.50        0.069287        0.415685
#                   half_robot           49.00        0.181653        0.264260
#                   half_robot_touch     49.25        0.093800        0.222675
#           forearm full                 69.25        0.060049        0.124152
#                   full_robot           17.50        0.054012        0.397653
#                   half_robot           49.00        0.062517        0.191826
#                   half_robot_touch     49.25        0.039450        0.188009
#           trunk   full                 69.25        0.085858        0.301744
#                   full_robot           17.50        0.107030        0.417183
#                   half_robot           49.00        0.141237        0.217395
#                   half_robot_touch     49.25        0.073053        0.230172
# x         arm     full                 69.25        0.342226        0.122369
#                   full_robot           17.50        0.358953        0.151509
#                   half_robot           49.00        0.149116        0.133505
#                   half_robot_touch     49.25        0.286142        0.175345
#           forearm full                 69.25        0.300339        0.160370
#                   full_robot           17.50        0.587382        0.139823
#                   half_robot           49.00        0.254035        0.190346
#                   half_robot_touch     49.25        0.160694        0.087234
#           trunk   full                 69.25        0.323587        0.279115
#                   full_robot           17.50        0.288179        0.317031
#                   half_robot           49.00        0.205678        0.380321
#                   half_robot_touch     49.25        0.186794        0.197195
# y         arm     full                 69.25        0.305862        0.216104
#                   full_robot           17.50        0.638390        0.163331
#                   half_robot           49.00        0.466516        0.164401
#                   half_robot_touch     49.25        0.352687        0.116175
#           forearm full                 69.25        0.254415        0.322548
#                   full_robot           17.50        0.627815        0.139993
#                   half_robot           49.00        0.282628        0.208805
#                   half_robot_touch     49.25        0.211747        0.229533
#           trunk   full                 69.25        0.408542        0.386765
#                   full_robot           17.50        0.174148        0.212513
#                   half_robot           49.00        0.344729        0.257840
#                   half_robot_touch     49.25        0.281148        0.243222
# z         arm     full                 69.25        0.508561        0.314547
#                   full_robot           17.50        0.721469        0.211553
#                   half_robot           49.00        0.434304        0.204343
#                   half_robot_touch     49.25        0.560983        0.281318
#           forearm full                 69.25        0.391985        0.223489
#                   full_robot           17.50        0.307543        0.167553
#                   half_robot           49.00        0.310902        0.181585
#                   half_robot_touch     49.25        0.240593        0.151832
#           trunk   full                 69.25        0.517251        0.300765
#                   full_robot           17.50        0.375887        0.175813
#                   half_robot           49.00        0.477760        0.185481
#                   half_robot_touch     49.25        0.396458        0.133671

# %%
plots_imu.plot_parameters(glob, 'trunk', 'acc')
